# %% [markdown]
# ## Ejercicio K-Smoothing
#
# En base al siguiente corpus, implemente los siguientes incisos.

# %%
corpus = ["la", "tarea", "esta", "muy", "larga"]

# %% [markdown]
# 1. Calcule la Frecuencia de las palabras
#
# 2. Calcule la probabilidad de cada palabra sin implementar Smoothing
#
# 3. Introduzca las siguientes palabras que no están en el corpus original:
#    a. hola
#    b. computadora
#
# 4. Implemente el algoritmo de *K-Smoothing*
#
#    ![image.png](attachment:image.png)
#
#    Donde
#    - C(W_i): es la frecuencia de w_i
#    - V: tamaño del vocabulario.
#    - N: Número de tokens a generar.
#
# 5. Utilice el algoritmo con k=0.5 para calcular nuevamente las probabilidades de las nuevas palabras.
# 6. Compare los resultados de ambasimplementaciones (con y sin smoothing).
